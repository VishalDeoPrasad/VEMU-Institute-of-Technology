# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,5,7,9,11]

plt.plot(x,y)

# %%
year  = [2018, 2019, 2020, 2021, 2022, 2023, 2024]
sales = [25000, 30000, 31000, 33000, 35000, 37000, 40000]

plt.plot(year, sales)

# %%
size = ['S', 'M', 'L', 'XL']
qty = [20, 17, 10, 13]

plt.bar(size, qty)
# Out:
# <BarContainer object of 4 artists>

# %%
size = ['S', 'M', 'L', 'XL']
qty = [20, 17, 10, 13]

plt.barh(size, qty)
# Out:
# <BarContainer object of 4 artists>

# %%
age = [12, 4, 56, 20, 12, 56, 67, 33, 19, 37, 12, 23, 89]

plt.hist(age)
# Out:
# (array([4., 2., 1., 2., 0., 0., 2., 1., 0., 1.]),
#  array([ 4. , 12.5, 21. , 29.5, 38. , 46.5, 55. , 63.5, 72. , 80.5, 89. ]),
#  <BarContainer object of 10 artists>)

# %%
x = [1,2,3,4,5]
y = [10,8,6,4,2]

plt.scatter(x, y)

# %%
size = ['S', 'M', 'L', 'XL']
qty = [30, 25, 20, 25]

plt.pie(qty, labels=size, autopct='%1.1f%%');

# %%
import seaborn as sns
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(x='year', y='passengers', data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.histplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'])
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df)

# %%
import pandas as pd
df = pd.read_csv("rapido_data.csv")
df
# Out:
#          services        date      time ride_status  \
# 0            bike  2024-06-23  19:18:20   completed
# 1       bike lite  2024-07-06   2:42:20   completed
# 2          parcel  2024-07-19  17:55:20   completed
# 3            bike  2024-07-20   5:38:20   cancelled
# 4     cab economy  2024-07-12  19:36:20   completed
# ...           ...         ...       ...         ...
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 0             Banashankari 7th Stage              Richmond Road        99
# 1                  Indiranagar North              Sahakar Nagar        48
# 2        MG Road Mahatma Gandhi Road           Whitefield South       112
# ...

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 3         bike  2024-07-20   5:38:20   cancelled                     JP Nagar
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
#
#              destination  duration             ride_id  distance  ride_charge  \
# 0          Richmond Road        99  RD8660319589404637     18.68        93.09
# 1          Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2       Whitefield South       112  RD1526455182706880      5.85       247.90
# 3  Rajajinagar 7th Block        45  RD7207154929912440     16.64          NaN
# 4  Brigade Road Eva Mall        44  RD6627722888214728      5.61       786.30
#
# ...

# %%
df.tail()
# Out:
#          services        date      time ride_status  \
# 9995         auto  2024-07-01   9:57:20   cancelled
# 9996   auto share  2024-07-10   2:47:20   completed
# 9997   auto share  2024-07-06  23:56:20   cancelled
# 9998  cab premium  2024-07-23   6:10:20   cancelled
# 9999  cab economy  2024-07-20   7:42:20   completed
#
#                               source                destination  duration  \
# 9995  Brigade Road Mota Royal Arcade                Neelasandra       120
# 9996                     Frazer Town        MG Road Cubbon Park        71
# 9997      Brigade Road Church Street  HSR Layout Sector 5 North        71
# 9998           Rajajinagar 2nd Block         HSR Layout Central        26
# 9999                    Hebbal North       HSR Layout Sector 10        88
#
#                  ride_id  distance  ride_charge  misc_charge  total_fare  \
# 9995  RD8489738606219832     10.70          NaN          NaN         NaN
# ...

# %%
df.isnull().sum()
# Out:
# services             0
# date                 0
# time                 0
# ride_status          0
# source               0
# destination          0
# duration             0
# ride_id              0
# distance             0
# ride_charge       5389
# misc_charge       5389
# total_fare        5389
# payment_method    5389
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# services          0
# date              0
# time              0
# ride_status       0
# source            0
# destination       0
# duration          0
# ride_id           0
# distance          0
# ride_charge       0
# misc_charge       0
# total_fare        0
# payment_method    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='object')

# %%
df['datetime'] = pd.to_datetime(df.date +" "+ df.time)

# %%
df.head(3)
# Out:
#     services        date      time ride_status                       source  \
# 0       bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1  bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2     parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
#
#         destination  duration             ride_id  distance  ride_charge  \
# 0     Richmond Road        99  RD8660319589404637     18.68        93.09
# 1     Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2  Whitefield South       112  RD1526455182706880      5.85       247.90
#
#    misc_charge  total_fare payment_method            datetime
# 0         2.32       95.41     Amazon Pay 2024-06-23 19:18:20
# 1        11.68      432.45        QR scan 2024-07-06 02:42:20
# 2        27.45      275.35           GPay 2024-07-19 17:55:20

# %%
sns.countplot(x='services', data=df)
# Out:
# <Axes: xlabel='services', ylabel='count'>

# %%
df.head(3)
# Out:
#     services        date      time ride_status                       source  \
# 0       bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1  bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2     parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
#
#         destination  duration             ride_id  distance  ride_charge  \
# 0     Richmond Road        99  RD8660319589404637     18.68        93.09
# 1     Sahakar Nagar        48  RD4484661533610497     42.55       420.77
# 2  Whitefield South       112  RD1526455182706880      5.85       247.90
#
#    misc_charge  total_fare payment_method            datetime
# 0         2.32       95.41     Amazon Pay 2024-06-23 19:18:20
# 1        11.68      432.45        QR scan 2024-07-06 02:42:20
# 2        27.45      275.35           GPay 2024-07-19 17:55:20

# %%
sns.barplot(x='services', y='total_fare', data=df)
# Out:
# <Axes: xlabel='services', ylabel='total_fare'>

# %%
df.head()
# Out:
#       services        date      time ride_status                       source  \
# 0         bike  2024-06-23  19:18:20   completed       Banashankari 7th Stage
# 1    bike lite  2024-07-06   2:42:20   completed            Indiranagar North
# 2       parcel  2024-07-19  17:55:20   completed  MG Road Mahatma Gandhi Road
# 4  cab economy  2024-07-12  19:36:20   completed             Whitefield North
# 6    bike lite  2024-07-01  22:54:20   completed             Kadubeesanahalli
#
#               destination  duration             ride_id  distance  \
# 0           Richmond Road        99  RD8660319589404637     18.68
# 1           Sahakar Nagar        48  RD4484661533610497     42.55
# 2        Whitefield South       112  RD1526455182706880      5.85
# 4   Brigade Road Eva Mall        44  RD6627722888214728      5.61
# 6  Banashankari 2nd Stage        30  RD1872668675732568     11.61
#
#    ride_charge  misc_charge  total_fare payment_method            datetime
# ...

# %%
df.duration
# Out:
# 0        99
# 1        48
# 2       112
# 4        44
# 6        30
#        ...
# 9988    105
# 9990     67
# 9993     57
# 9996     71
# 9999     88
# Name: duration, Length: 4611, dtype: int64

# %%
sns.histplot(df.duration)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %%
sns.barplot(x='services', y='distance', data=df, estimator=sum)
# Out:
# <Axes: xlabel='services', ylabel='distance'>

# %%
import pandas as pd
df = pd.read_csv("Cars24 data.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.fuel.unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df.fuel.value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df.fuel.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
df.groupby('fuel')['selling_price'].mean()
# Out:
# fuel
# CNG       301017.491228
# Diesel    791452.921627
# LPG       200421.052632
# Petrol    462441.061691
# Name: selling_price, dtype: float64

# %%
df.groupby('fuel')['selling_price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
df.head(3)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
#
#                   torque  seats
# 0         190Nm@ 2000rpm    5.0
# 1    250Nm@ 1500-2500rpm    5.0
# 2  12.7@ 2,700(kgm@ rpm)    5.0

# %%
df.plot.scatter(x="km_driven", y='selling_price')
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %%
df.mileage = df.mileage.str.replace(" kmpl", "").str.replace(" km/kg","").astype(float)

# %%
df.max_power.str.replace(' bhp', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 df.max_power.str.replace(' bhp', '').astype(float)
#
# File c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner    23.40  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner    21.14  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner    17.70  1497 CC      78 bhp
# 3  Individual       Manual   First Owner    23.00  1396 CC      90 bhp
# 4  Individual       Manual   First Owner    16.10  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.seats.value_counts()
# Out:
# seats
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %%
df.seats.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='seats'>

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner    23.40  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner    21.14  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner    17.70  1497 CC      78 bhp
# 3  Individual       Manual   First Owner    23.00  1396 CC      90 bhp
# 4  Individual       Manual   First Owner    16.10  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
sns.boxplot(x='owner', y='selling_price', data=df)
# Out:
# <Axes: xlabel='owner', ylabel='selling_price'>
